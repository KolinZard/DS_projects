# %%
#библиотека для регулярных выражений
import re 
def get_year_release(arg):
    #находим все слова по шаблону "(DDDD)"
    candidates = re.findall(r'\(\d{4}\)', arg) 
    # проверяем число вхождений
    if len(candidates) > 0:
        #если число вхождений больше 0,
	#очищаем строку от знаков "(" и ")"
        year = candidates[0].replace('(', '')
        year = year.replace(')', '')
        return int(year)
    else:
        #если год не указан, возвращаем None
        return None

# %%
import pandas as pd

# %%
rating_movies = pd.read_csv('Data/ratings_movies.csv')

# %%
rating_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  100836 non-null  int64
#  1   userId      100836 non-null  int64
#  2   movieId     100836 non-null  int64
#  3   rating      100836 non-null  float64
#  4   date        100836 non-null  object
#  5   title       100836 non-null  object
#  6   genres      100836 non-null  object
#  7   year        100818 non-null  float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 6.2+ MB

# %%
rating_movies['year'] = rating_movies['title'].agg(get_year_release)
# Out:
# /var/folders/mj/6p8qfrq97ts_vlb1kk914kjc0000gn/T/ipykernel_844/1833136484.py:1: FutureWarning: using <function get_year_release at 0x1077c3160> in Series.agg cannot aggregate and has been deprecated. Use Series.transform to keep behavior unchanged.
#   rating_movies['year'] = rating_movies['title'].agg(get_year_release)

# %%
mask1 = rating_movies['year'] == 1999

# %%
rating_movies[mask1].groupby('title')['rating'].mean().sort_values().head(1)
# Out:
# title
# Bloodsport: The Dark Kumite (1999)    0.5
# Name: rating, dtype: float64

# %%
mask2 = rating_movies['year'] == 2010
rating_movies[mask2].groupby('genres')['rating'].mean().sort_values().head(1)
# Out:
# genres
# Action|Sci-Fi    1.0
# Name: rating, dtype: float64

# %%
rating_movies.groupby('userId')['genres'].nunique().sort_values(ascending=False)
# Out:
# userId
# 599    524
# 414    482
# 448    403
# 380    399
# 474    395
#       ...
# 578     15
# 12      15
# 85      13
# 214     13
# 245     13
# Name: genres, Length: 610, dtype: int64

# %%
rating_movies.groupby('userId')['rating'].agg(['count', 'mean']).sort_values(by=['count', 'mean'], ascending=[True, False])
# Out:
#         count      mean
# userId
# 53         20  5.000000
# 595        20  4.200000
# 189        20  4.100000
# 569        20  4.000000
# 278        20  3.875000
# ...       ...       ...
# 274      1346  3.235884
# 448      1864  2.847371
# 474      2108  3.398956
# 599      2478  2.642050
# 414      2698  3.391957
#
# [610 rows x 2 columns]

# %%
mask3 = rating_movies['year'] == 2018
table1 = rating_movies[mask3].groupby('genres')['rating'].agg(['mean','count'])
# display(table1)
mask4 = table1['count'] > 10
table1[mask4].sort_values(by='mean', ascending=False).head(1)
# Out:
#                              mean  count
# genres
# Action|Adventure|Sci-Fi  3.928571     14

# %%
rating_movies['date'] = pd.to_datetime(rating_movies['date'])

# %%
rating_movies['year rating'] = rating_movies['date'].dt.year

# %%
rating_movies_pivot = rating_movies.pivot_table(
    values='rating',
    index= 'year rating',
    columns= 'genres',
    aggfunc= 'mean'
)

display(rating_movies_pivot)
# Out:
# genres       (no genres listed)    Action  Action|Adventure  \
# year rating
# 1996                        NaN  2.730769          3.454545
# 1997                        NaN  3.538462          4.150000
# 1998                        NaN       NaN          4.200000
# 1999                        NaN       NaN          4.000000
# 2000                        NaN  2.588235          3.738462
# 2001                        NaN  3.000000          3.500000
# 2002                        NaN  2.750000          4.304348
# 2003                        NaN  3.833333          3.277778
# 2004                        NaN  2.700000          4.136364
# 2005                        NaN  3.357143          3.413043
# 2006                        NaN  2.166667          4.090909
# 2007                        NaN  2.583333          3.666667
# 2008                        NaN  3.000000          3.656250
# 2009                        NaN       NaN          3.714286
# ...

# %%
import pandas as pd
orders = pd.read_csv('Data/orders.csv', sep=';')
display(orders)
products = pd.read_csv('Data/products.csv', sep=';')
display(products)
# Out:
#           Дата создания  Order ID  ID Покупателя  \
# 0   09.11.2019 21:55:51         9             10
# 1   09.11.2019 15:05:57         8              9
# 2   09.11.2019 15:05:57         8              9
# 3   09.11.2019 12:50:07         7              8
# 4   09.11.2019 12:00:00         6              1
# 5   09.11.2019 12:00:00         6              1
# 6   08.11.2019 08:36:22         5              5
# 7   08.11.2019 08:36:22         4              9
# 8   08.11.2019 08:36:22         3              8
# 9   08.11.2019 08:36:22         3              8
# 10  08.11.2019 08:36:21         2              7
# 11  08.11.2019 08:36:21         2              7
# 12  08.11.2019 08:36:21         2              7
# 13  08.11.2019 08:36:21         2              7
# 14  08.11.2019 08:36:20         1              5
# 15  08.11.2019 08:36:20         1              5
# 16  08.11.2019 08:36:20         1              5
# 17  01.01.2001 00:00:00         0              1
#
# ...

# %%
orders_products = orders.merge(
    products,
    how='outer',
    left_on='ID товара',
    right_on='Product_ID'
)
orders_products.groupby('ID Покупателя')['Price'].sum().sort_values(ascending=False).head(1)
# Out:
# ID Покупателя
# 7.0    17096.0
# Name: Price, dtype: float64
